# %%
# !pip install git+git://github.com/thomaspernet/GoogleDrive-python
# Out:
# ...
#   Cloning git://github.com/thomaspernet/GoogleDrive-python to /tmp/pip-req-build-f_epr02o
# Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-req-build-f_epr02o/
