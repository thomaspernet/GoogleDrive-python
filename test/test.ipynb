# %%
#!pip install git+git://github.com/thomaspernet/GoogleDrive-python
# !pip install --upgrade git+git://github.com/thomaspernet/GoogleDrive-python
# Out:
# Collecting git+git://github.com/thomaspernet/GoogleDrive-python
#   Cloning git://github.com/thomaspernet/GoogleDrive-python to /tmp/pip-req-build-ioxy7edq
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.6/dist-packages (from GoogleDrivePy==0.2) (0.22.0)
# Requirement already satisfied, skipping upgrade: oauth2client in /usr/local/lib/python3.6/dist-packages (from GoogleDrivePy==0.2) (4.1.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas->GoogleDrivePy==0.2) (1.14.6)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->GoogleDrivePy==0.2) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas->GoogleDrivePy==0.2) (2.5.3)
# Requirement already satisfied, skipping upgrade: six>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client->GoogleDrivePy==0.2) (1.11.0)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client->GoogleDrivePy==0.2) (4.0)
# Requirement already satisfied, skipping upgrade: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client->GoogleDrivePy==0.2) (0.11.3)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client->GoogleDrivePy==0.2) (0.4.5)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client->GoogleDrivePy==0.2) (0.2.4)
# Building wheels for collected packages: GoogleDrivePy
#   Building wheel for GoogleDrivePy (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8xx8_60m/wheels/2f/f1/f1/064d6a7ba18e02fe3bcd341830dd738aa2a202a15cecb2b2c2
# Successfully built GoogleDrivePy
# Installing collected packages: GoogleDrivePy
#   Found existing installation: GoogleDrivePy 0.2
#     Uninstalling GoogleDrivePy-0.2:
#       Successfully uninstalled GoogleDrivePy-0.2
# Successfully installed GoogleDrivePy-0.2

# %% [markdown]
# # Connect service

# %%
from GoogleDrivePy.authentification import connect_service

# %%
pathcredential = '/content/gdrive/My Drive/Projects/Google_code_n_Oauth/Client_Oauth/Google_auth/'
scopes = ['https://www.googleapis.com/auth/documents.readonly',
            'https://www.googleapis.com/auth/drive']
cs = connect_service.connect_service(pathcredential, scopes)

# %%
cs.get_auth()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
service = cs.get_service()
# Out:
# Service Google Drive and Google Docs are now connected.
# Service Google Drive is stored as <googleapiclient.discovery.Resource object at 0x7f49d0c9bd68> and accessible with "drive"
# Service Google Doc is stored as <googleapiclient.discovery.Resource object at 0x7f49d0c94ac8>and accessible with "doc"

# %% [markdown]
# # Google Drive

# %%
from GoogleDrivePy.google_drive import connect_drive
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-4a3275ed75cd> in <module>()
# ----> 1 from GoogleDrivePy.google_drive import connect_drive
#
# ModuleNotFoundError: No module named 'GoogleDrivePy.google_drive'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
