# %%
#!pip install git+git://github.com/thomaspernet/GoogleDrive-python
# !pip install --upgrade git+git://github.com/thomaspernet/GoogleDrive-python
# Out:
# Collecting git+git://github.com/thomaspernet/GoogleDrive-python
#   Cloning git://github.com/thomaspernet/GoogleDrive-python to /tmp/pip-req-build-1npeehsx
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.6/dist-packages (from GoogleDrivePy==0.1) (0.22.0)
# Requirement already satisfied, skipping upgrade: oauth2client in /usr/local/lib/python3.6/dist-packages (from GoogleDrivePy==0.1) (4.1.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas->GoogleDrivePy==0.1) (1.14.6)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->GoogleDrivePy==0.1) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas->GoogleDrivePy==0.1) (2.5.3)
# Requirement already satisfied, skipping upgrade: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client->GoogleDrivePy==0.1) (0.11.3)
# Requirement already satisfied, skipping upgrade: six>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client->GoogleDrivePy==0.1) (1.11.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client->GoogleDrivePy==0.1) (0.2.4)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client->GoogleDrivePy==0.1) (0.4.5)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client->GoogleDrivePy==0.1) (4.0)
# Building wheels for collected packages: GoogleDrivePy
#   Building wheel for GoogleDrivePy (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_bj_83ef/wheels/2f/f1/f1/064d6a7ba18e02fe3bcd341830dd738aa2a202a15cecb2b2c2
# Successfully built GoogleDrivePy
# Installing collected packages: GoogleDrivePy
#   Found existing installation: GoogleDrivePy 0.1
#     Uninstalling GoogleDrivePy-0.1:
#       Successfully uninstalled GoogleDrivePy-0.1
# Successfully installed GoogleDrivePy-0.1

# %%
from GoogleDrivePy.authentification import connect_service

# %%
pathcredential = '/content/gdrive/My Drive/Projects/Google_code_n_Oauth/Client_Oauth/Google_auth/'
scopes = ['https://www.googleapis.com/auth/documents.readonly',
            'https://www.googleapis.com/auth/drive']
cs = connect_service.connect_service(pathcredential, scopes)

# %%
cs.get_auth()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fd0e6572933a> in <module>()
# ----> 1 cs.get_auth()
#
# NameError: name 'cs' is not defined

# %%
cs.get_service()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6e3ec34f7956> in <module>()
# ----> 1 cs.get_service()
#
# /usr/local/lib/python3.6/dist-packages/GoogleDrivePy/authentification/connect_service.py in get_service(self)
#      37                         flow = client.flow_from_clientsecrets(path_credential, self.scope)
#      38                         creds = tools.run_flow(flow, store)
# ---> 39                 service = build('drive', 'v3', http=creds.authorize(Http()))
#      40                 service_doc = build('docs', 'v1', http=creds.authorize(Http()))
#      41 		service = {
#
# NameError: name 'build' is not defined
