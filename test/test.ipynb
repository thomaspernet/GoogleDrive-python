# %%
# !pip install git+git://github.com/thomaspernet/GoogleDrive-python
# Out:
# Collecting git+git://github.com/thomaspernet/GoogleDrive-python
#   Cloning git://github.com/thomaspernet/GoogleDrive-python to /tmp/pip-req-build-u0jmqi58
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from GoogleDrivePy==0.1) (0.22.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->GoogleDrivePy==0.1) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas->GoogleDrivePy==0.1) (2.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas->GoogleDrivePy==0.1) (1.14.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas->GoogleDrivePy==0.1) (1.11.0)
# Building wheels for collected packages: GoogleDrivePy
#   Building wheel for GoogleDrivePy (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tsdrlsx2/wheels/2f/f1/f1/064d6a7ba18e02fe3bcd341830dd738aa2a202a15cecb2b2c2
# Successfully built GoogleDrivePy
# Installing collected packages: GoogleDrivePy
# Successfully installed GoogleDrivePy-0.1

# %%
from GoogleDrivePy.authentification import connect_service

# %%
pathcredential = '/content/gdrive/My Drive/Projects/Google_code_n_Oauth/Client_Oauth/Google_auth/'
scopes = ['https://www.googleapis.com/auth/documents.readonly',
            'https://www.googleapis.com/auth/drive']
cs = connect_service.connect_service(pathcredential, scopes)

# %%
cs.get_auth()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cs.get_service()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-6e3ec34f7956> in <module>()
# ----> 1 cs.get_service()
#
# /usr/local/lib/python3.6/dist-packages/GoogleDrivePy/authentification/connect_service.py in get_service(self)
#      29 		"""
#      30
# ---> 31                 path_token = self.path + "token.json"
#      32                 path_credential = self.path + "credentials.json"
#      33                 store = file.Storage(path_token)
#
# AttributeError: 'connect_service' object has no attribute 'path'
