# %%
# !pip install git+git://github.com/thomaspernet/GoogleDrive-python
# Out:
# ...
#   Cloning git://github.com/thomaspernet/GoogleDrive-python to /tmp/pip-req-build-gi62ip_6
# Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-req-build-gi62ip_6/
